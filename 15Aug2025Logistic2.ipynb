# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmedebeed555/LogisticRegression/blob/main/15Aug2025Logistic2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns

from sklearn.linear_model import LogisticRegression
from sklearn.datasets import make_classification

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
X,y = make_classification(n_features=2, n_samples=1000, n_clusters_per_class=1 , n_redundant=0, n_informative=2, random_state= 42 )

# %%
df = pd.DataFrame(X, columns=['x1' , 'x2'])
df['y'] = y

# %%
df.head()
# Out:
#          x1        x2  y
# 0  0.601034  1.535353  1
# 1  0.755945 -1.172352  0
# 2  1.354479 -0.948528  0
# 3  3.103090  0.233485  0
# 4  0.753178  0.787514  1

# %%
plt.scatter(df['x1'], df['x2'], c=df['y'],alpha=0.7)
